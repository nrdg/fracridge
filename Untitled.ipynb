# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import pinv, svd

# %%
def ols(X, y): 
    return pinv(X.T @ X) @ X.T @ y.T

# %%
def rr(X, y, alpha=0):
    return pinv(X.T @ X + alpha * np.eye(X.shape[1])) @ X.T @ y.T

# %%
p = 120
d = 100

# %%
p / d
# Out:
# 1.2

# %%
X = np.random.randn(d, p)

# %%
beta = np.random.randn(p)

# %%
sigma = 10

# %%
epsilon = np.random.randn(d) * sigma

# %%
y = X @ beta + epsilon

# %%
beta_hat_ols = ols(X, y)

# %%
y_hat = X @ beta_hat_ols

# %%
plt.scatter(y, y_hat)

# %%
plt.bar(range(len(y)), y - y_hat)
# Out:
# <BarContainer object of 100 artists>

# %%
from ridge_tools import frac_reduction, vec_len, reg_alpha_flat, optimize_for_frac

# %%
request_frac = np.arange(0.01, 1, 0.01)

# %%
request_alpha = optimize_for_frac(X, request_frac)

# %%
beta_ols = ols(X, y)

# %%
real_frac = []
for alpha in request_alpha:
    beta_rr = rr(X, y, alpha=alpha)
    real_frac.append(vec_len(beta_rr) / vec_len(beta_ols))

# %%
plt.plot(request_frac, real_frac)

# %%
plt.plot(request_frac, real_frac/request_frac)

# %%
real_frac[49], request_frac[49]
# Out:
# (0.5198453925410637, 0.5)

# %%
plt.plot(request_frac, request_alpha)
